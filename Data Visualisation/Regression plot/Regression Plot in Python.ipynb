# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df  = pd.read_csv("scatter_plot_ii.csv")
df
# Out:
#      Budget  Sales
# 0     337.1   22.1
# 1     128.9   10.4
# 2     132.4    9.3
# 3     251.3   18.5
# 4     250.0   12.9
# ..      ...    ...
# 195    55.7    7.6
# 196   107.2    9.7
# 197   192.7   12.8
# 198   391.8   25.5
# 199   249.4   13.4
#
# [200 rows x 2 columns]

# %%
plt.figure(figsize=(10,8))
sns.regplot(data=df,
           x="Budget",
           y="Sales",
           scatter_kws = {"color": "black"},
           line_kws = {"color": "red"})
plt.xlabel("Ad Expenditure (K$)",
          fontsize = 12)
plt.ylabel("Sales (KUnits)",
          fontsize = 12)
plt.title("Effect of Ad Expenditure on Sales", 
         fontsize = 14,
         weight = "bold")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.lmplot(data=df,
           x="Budget",
           y="Sales",
           scatter_kws = {"color": "black"},
           line_kws = {"color": "red"},
          height=9)
plt.xlabel("Ad Expenditure (K$)",
          fontsize = 12)
plt.ylabel("Sales (KUnits)",
          fontsize = 12)
plt.title("Effect of Ad Expenditure on Sales", 
         fontsize = 14,
         weight = "bold")
plt.show()
