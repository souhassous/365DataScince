# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
df = pd.read_csv("scatter_data.csv")
df
# Out:
#        ID  Building Type  Year of sale  Month of sale Type of property  \
# 0    1030              1        2005.0           11.0        Apartment
# 1    1029              1        2005.0           10.0        Apartment
# 2    2002              2        2007.0            7.0        Apartment
# 3    2031              2        2007.0           12.0        Apartment
# 4    1049              1        2004.0           11.0        Apartment
# ..    ...            ...           ...            ...              ...
# 262  5044              5           NaN            NaN        Apartment
# 263  5047              5           NaN            NaN        Apartment
# 264  5048              5           NaN            NaN        Apartment
# 265  5050              5           NaN            NaN        Apartment
# 266  5051              5           NaN            NaN        Apartment
#
#      Property #  Area (ft.)      Price    Status
# 0            30      743.09  246.17268     Sold
# ...

# %%
plt.figure(figsize=(12,8))
#sns.set_style("white")
scatter  = plt.scatter(df["Area (ft.)"],
           df["Price"],
           alpha=0.5,
           c = df["Building Type"],
           cmap="viridis")
plt.legend(*scatter.legend_elements(), 
          loc = "upper left",
          title = "Building Type")

plt.title("Relationship between Area and Prices of California Real Estate",
         fontsize = 16,
         weight ="bold",
         color = "navy",
         loc = "left")
plt.xlabel("Areas (sq. ft)", 
          fontsize = 12,
          weight = "bold",
          color = "navy")
plt.ylabel("Prices (K$)",
          fontsize = 12,
          weight = "bold",
          color = "navy")
plt.xticks(color = "navy", 
           weight = "bold")
plt.yticks(color = "navy",
          weight = "bold")
sns.despine()
plt.show()

# %%
plt.figure(figsize=(12,8))
#sns.set_style("white")

sns.scatterplot(x=df["Area (ft.)"],
               y=df["Price"],
               hue=df["Building Type"],
               palette=['black', 'darkblue', 'purple', 'pink', 'white'],
               s = 100)

plt.title("Relationship between Area and Prices of California Real Estate",
         fontsize = 16,
         weight ="bold",
         color = "navy",
         loc = "left")
plt.xlabel("Areas (sq. ft)", 
          fontsize = 12,
          weight = "bold",
          color = "navy")
plt.ylabel("Prices (K$)",
          fontsize = 12,
          weight = "bold",
          color = "navy")
plt.xticks(color = "navy", 
           weight = "bold")
plt.yticks(color = "navy",
          weight = "bold")
sns.despine()
plt.show()
