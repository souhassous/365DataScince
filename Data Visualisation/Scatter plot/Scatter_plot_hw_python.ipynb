# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
df = pd.read_csv("student_scores_data.csv")
df
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
plt.figure (figsize=(12,8))
plt.scatter(x=df["SAT"],
           y=df["GPA"],
           color = "darkblue",
           alpha= 0.6)

plt.title("Relationship between SAT & GPA scores of student",
          fontsize = 16,
          weight = "bold",
          color = "darkblue")
plt.xlabel("SAT Scores", 
           fontsize = 13,
           weight = "bold",
           color = "darkblue")
plt.ylabel("GPA Scores",
           fontsize = 13,
           weight ="bold",
           color = "darkblue")
plt.show()

# %%
plt.figure (figsize=(12,8))
plt.scatter(x=df["SAT"],
           y=df["GPA"],
           color = "darkblue",
           alpha= 0.6)

plt.title("Relationship between SAT & GPA scores of student",
          fontsize = 16,
          weight = "bold",
          color = "darkblue")
plt.xlabel("SAT Scores", 
           fontsize = 13,
           weight = "bold",
           color = "darkblue")
plt.ylabel("GPA Scores",
           fontsize = 13,
           weight ="bold",
           color = "darkblue")
plt.xlim(0, max(df["SAT"]+500))
plt.ylim(0, max(df["GPA"]+1))
plt.show()
